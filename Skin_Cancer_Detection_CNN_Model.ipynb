# %% [markdown]
# # Detecting and Classifying Skin Cancers With CNN Model

# %% [markdown]
# ### Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load Dataset of Skin Images From Kaggle

# %%
# !mkdir -p  ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d nodoubttome/skin-cancer9-classesisic
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/nodoubttome/skin-cancer9-classesisic
# License(s): other
# Downloading skin-cancer9-classesisic.zip to /content
#  98% 771M/786M [00:09<00:00, 123MB/s]
# 100% 786M/786M [00:09<00:00, 88.5MB/s]

# %%
# Extract skin images from our zip file
import zipfile
zip_ref = zipfile.ZipFile('/content/skin-cancer9-classesisic.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# ### Import Libraries

# %%
import os
import cv2
import shutil
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
from sklearn.metrics import f1_score

import tensorflow
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from  tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from keras.optimizers import Adam, SGD

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### Define Paths for our Skin Images

# %%
dirpath = os.getcwd()
PATH = os.path.join(dirpath, 'Skin cancer ISIC The International Skin Imaging Collaboration')
PATH_ak = os.path.join(PATH, 'Train/actinic keratosis')
PATH_bcc = os.path.join(PATH, 'Train/basal cell carcinoma')
PATH_derm = os.path.join(PATH, 'Train/dermatofibroma')
PATH_mel = os.path.join(PATH, 'Train/melanoma')
PATH_nev = os.path.join(PATH, 'Train/nevus')
PATH_pbk = os.path.join(PATH, 'Train/pigmented benign keratosis')
PATH_sk = os.path.join(PATH, 'Train/seborrheic keratosis')
PATH_scc = os.path.join(PATH, 'Train/squamous cell carcinoma')
PATH_vl = os.path.join(PATH, 'Train/vascular lesion')
class_names = ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Divide Paths for Images in Each Category

# %%
files_ak = os.listdir(PATH_ak)
files_bcc = os.listdir(PATH_bcc)
files_derm = os.listdir(PATH_derm)
files_mel = os.listdir(PATH_mel)
files_nev = os.listdir(PATH_nev)
files_pbk = os.listdir(PATH_pbk)
files_sk = os.listdir(PATH_sk)
files_scc = os.listdir(PATH_scc)
files_vl = os.listdir(PATH_vl)
print(len(files_ak), len(files_bcc), len(files_derm), len(files_mel), len(files_nev), len(files_pbk), len(files_sk), len(files_scc), len(files_vl))

paths_ak = [os.path.join(PATH_ak, file) for file in files_ak]
paths_bcc = [os.path.join(PATH_bcc, file) for file in files_bcc]
paths_derm = [os.path.join(PATH_derm, file) for file in files_derm]
paths_mel = [os.path.join(PATH_mel, file) for file in files_mel]
paths_nev = [os.path.join(PATH_nev, file) for file in files_nev]
paths_pbk = [os.path.join(PATH_pbk, file) for file in files_pbk]
paths_sk = [os.path.join(PATH_sk, file) for file in files_sk]
paths_scc = [os.path.join(PATH_scc, file) for file in files_scc]
paths_val = [os.path.join(PATH_vl, file) for file in files_vl]

# Number of paths per skin cancer category
paths_all = np.concatenate([paths_ak, paths_bcc, paths_derm, paths_mel, paths_nev, paths_pbk, paths_sk, paths_scc, paths_val])
# Out:
# 114 376 95 438 357 462 77 181 139

# %% [markdown]
# ### Crop our Images and Define New Paths

# %%
# Set a target size to crop our images at
target_size =  (256, 256)

# Define function to center crop our images
def crop_center_opencv(image, size):
  height, width = image.shape[:2]
  top = (height - size[1]) // 2
  bottom = top + size[1]
  left = (width - size[0]) // 2
  right = left + size[0]
  return image[top:bottom, left:right]

category_paths = [PATH_ak, PATH_bcc, PATH_derm,  PATH_mel, PATH_nev, PATH_pbk, PATH_sk, PATH_scc, PATH_vl]

# Create directory folder to store our cropped images
cropped_dir = os.path.join(dirpath, 'Cropped_Images')
os.makedirs(cropped_dir, exist_ok=True)

# Nested for loops to resize and crop our images for processing
for i, category_path in enumerate(category_paths):
  category_name = class_names[i]
  save_dir = os.path.join(cropped_dir, category_name)
  os.makedirs(save_dir, exist_ok=True)

  files = os.listdir(category_path)

  for file in files:
    image_path = os.path.join(category_path, file)
    image = cv2.imread(image_path)

    height, width = image.shape[:2]
    if height < width:
      new_height = target_size[1]
      new_width = int(width * (new_height / height))
    else:
      new_width = target_size[0]
      new_height = int(height * (new_width / width))

    resized_image = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
    cropped_image = crop_center_opencv(resized_image, target_size)

    save_path = os.path.join(save_dir, file)
    cv2.imwrite(save_path, cropped_image)

print("All images have been cropped and saved")

# Create paths for our cropped images
cropped_PATH = os.path.join(dirpath, 'Cropped_Images')
cropped_ak = os.path.join(cropped_PATH, 'actinic keratosis')
cropped_bcc = os.path.join(cropped_PATH, 'basal cell carcinoma')
cropped_derm = os.path.join(cropped_PATH, 'dermatofibroma')
cropped_mel = os.path.join(cropped_PATH, 'melanoma')
cropped_nev = os.path.join(cropped_PATH, 'nevus')
cropped_pbk = os.path.join(cropped_PATH, 'pigmented benign keratosis')
cropped_sk = os.path.join(cropped_PATH, 'seborrheic keratosis')
cropped_scc = os.path.join(cropped_PATH, 'squamous cell carcinoma')
cropped_vl = os.path.join(cropped_PATH, 'vascular lesion')

cropped_files_ak = os.listdir(cropped_ak)
cropped_files_bcc = os.listdir(cropped_bcc)
cropped_files_derm = os.listdir(cropped_derm)
cropped_files_mel = os.listdir(cropped_mel)
cropped_files_nev = os.listdir(cropped_nev)
cropped_files_pbk = os.listdir(cropped_pbk)
cropped_files_sk = os.listdir(cropped_sk)
cropped_files_scc = os.listdir(cropped_scc)
cropped_files_vl = os.listdir(cropped_vl)

cropped_paths_ak = [os.path.join(cropped_ak, file) for file in cropped_files_ak]
cropped_paths_bcc = [os.path.join(cropped_bcc, file) for file in cropped_files_bcc]
cropped_paths_derm = [os.path.join(cropped_derm, file) for file in cropped_files_derm]
cropped_paths_mel = [os.path.join(cropped_mel, file) for file in cropped_files_mel]
cropped_paths_nev = [os.path.join(cropped_nev, file) for file in cropped_files_nev]
cropped_paths_pbk = [os.path.join(cropped_pbk, file) for file in cropped_files_pbk]
cropped_paths_sk = [os.path.join(cropped_sk, file) for file in cropped_files_sk]
cropped_paths_scc = [os.path.join(cropped_scc, file) for file in cropped_files_scc]
cropped_paths_val = [os.path.join(cropped_vl, file) for file in cropped_files_vl]

df_ak = pd.DataFrame({'image': cropped_paths_ak, 'label': class_names[0]})
df_bcc = pd.DataFrame({'image': cropped_paths_bcc, 'label': class_names[1]})
df_derm = pd.DataFrame({'image': cropped_paths_derm, 'label': class_names[2]})
df_mel = pd.DataFrame({'image': cropped_paths_mel, 'label': class_names[3]})
df_nev = pd.DataFrame({'image': cropped_paths_nev, 'label': class_names[4]})
df_pbk = pd.DataFrame({'image': cropped_paths_pbk, 'label': class_names[5]})
df_sk = pd.DataFrame({'image': cropped_paths_sk, 'label': class_names[6]})
df_scc = pd.DataFrame({'image': cropped_paths_scc, 'label': class_names[7]})
df_vl = pd.DataFrame({'image': cropped_paths_val, 'label': class_names[8]})

# DataFrame of image paths and their label to train
train_data = pd.concat([df_ak, df_bcc, df_derm, df_mel, df_nev, df_pbk, df_sk, df_scc, df_vl])
# Out:
# All images have been cropped and saved

# %% [markdown]
# ### Display The Number of Images per Category

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x=train_data.label, hue = train_data.label, legend = False)
ax.set_xlabel("Class")
ax.set_ylabel("Count")
plt.title("The Number Of Samples For Each Class In Train")
plt.grid(True)
plt.xticks(rotation=-90)
plt.show()

# %% [markdown]
# #### Display Random Defect Image From Each Category

# %%
# Get 3 random images from each category to display
im_ak = [Image.open(os.path.join(PATH_ak, files_ak[np.random.randint(0, len(files_ak))])).convert('RGB'),
        Image.open(os.path.join(PATH_ak, files_ak[np.random.randint(0, len(files_ak))])).convert('RGB'),
        Image.open(os.path.join(PATH_ak, files_ak[np.random.randint(0, len(files_ak))])).convert('RGB')]
im_bcc = [Image.open(os.path.join(PATH_bcc, files_bcc[np.random.randint(0, len(files_bcc))])).convert('RGB'),
          Image.open(os.path.join(PATH_bcc, files_bcc[np.random.randint(0, len(files_bcc))])).convert('RGB'),
          Image.open(os.path.join(PATH_bcc, files_bcc[np.random.randint(0, len(files_bcc))])).convert('RGB')]
im_derm = [Image.open(os.path.join(PATH_derm, files_derm[np.random.randint(0, len(files_derm))])).convert('RGB'),
          Image.open(os.path.join(PATH_derm, files_derm[np.random.randint(0, len(files_derm))])).convert('RGB'),
           Image.open(os.path.join(PATH_derm, files_derm[np.random.randint(0, len(files_derm))])).convert('RGB')]
im_mel = [Image.open(os.path.join(PATH_mel, files_mel[np.random.randint(0, len(files_mel))])).convert('RGB'),
          Image.open(os.path.join(PATH_mel, files_mel[np.random.randint(0, len(files_mel))])).convert('RGB'),
          Image.open(os.path.join(PATH_mel, files_mel[np.random.randint(0, len(files_mel))])).convert('RGB')]
im_nev = [Image.open(os.path.join(PATH_nev, files_nev[np.random.randint(0, len(files_nev))])).convert('RGB'),
          Image.open(os.path.join(PATH_nev, files_nev[np.random.randint(0, len(files_nev))])).convert('RGB'),
          Image.open(os.path.join(PATH_nev, files_nev[np.random.randint(0, len(files_nev))])).convert('RGB')]
im_pbk = [Image.open(os.path.join(PATH_pbk, files_pbk[np.random.randint(0, len(files_pbk))])).convert('RGB'),
          Image.open(os.path.join(PATH_pbk, files_pbk[np.random.randint(0, len(files_pbk))])).convert('RGB'),
          Image.open(os.path.join(PATH_pbk, files_pbk[np.random.randint(0, len(files_pbk))])).convert('RGB')]
im_sk = [Image.open(os.path.join(PATH_sk, files_sk[np.random.randint(0, len(files_sk))])).convert('RGB'),
         Image.open(os.path.join(PATH_sk, files_sk[np.random.randint(0, len(files_sk))])).convert('RGB'),
         Image.open(os.path.join(PATH_sk, files_sk[np.random.randint(0, len(files_sk))])).convert('RGB')]
im_scc = [Image.open(os.path.join(PATH_scc, files_scc[np.random.randint(0, len(files_scc))])).convert('RGB'),
          Image.open(os.path.join(PATH_scc, files_scc[np.random.randint(0, len(files_scc))])).convert('RGB'),
          Image.open(os.path.join(PATH_scc, files_scc[np.random.randint(0, len(files_scc))])).convert('RGB')]
im_vl = [Image.open(os.path.join(PATH_vl, files_vl[np.random.randint(0, len(files_vl))])).convert('RGB'),
         Image.open(os.path.join(PATH_vl, files_vl[np.random.randint(0, len(files_vl))])).convert('RGB'),
         Image.open(os.path.join(PATH_vl, files_vl[np.random.randint(0, len(files_vl))])).convert('RGB')]


# Display those 3 random images
fig, axs = plt.subplots(len(im_ak),9)
fig.set_figheight(10)
fig.set_figwidth(20)
fig.suptitle("Examples of Each Skin Cancer Type", fontsize=20)
for i, im in enumerate(im_ak):
  axs[i][0].imshow(im, vmin = 0, vmax = 225)
  axs[0][0].set_title('Actinic Keratosis', fontsize=10)
for i, im in enumerate(im_bcc):
  axs[i][1].imshow(im, vmin = 0, vmax=225)
  axs[0][1].set_title('Basal Cell Carcinoma', fontsize=10)
for i, im in enumerate(im_derm):
  axs[i][2].imshow(im, vmin = 0, vmax=225)
  axs[0][2].set_title('Dermatofibroma', fontsize=10)
for i, im in enumerate(im_mel):
  axs[i][3].imshow(im, vmin = 0, vmax=225)
  axs[0][3].set_title('Melanoma', fontsize=10)
for i, im in enumerate(im_nev):
  axs[i][4].imshow(im, vmin = 0, vmax=225)
  axs[0][4].set_title('Nevus', fontsize=10)
for i, im in enumerate(im_pbk):
  axs[i][5].imshow(im, vmin = 0, vmax=225)
  axs[0][5].set_title('Pigmented Benign Keratosis', fontsize=10)
for i, im in enumerate(im_sk):
  axs[i][6].imshow(im, vmin = 0, vmax=225)
  axs[0][6].set_title('Seborrheic Keratosis', fontsize=10)
for i, im in enumerate(im_scc):
  axs[i][7].imshow(im, vmin = 0, vmax=225)
  axs[0][7].set_title('Squamous Cell Carcinoma', fontsize=10)
for i, im in enumerate(im_vl):
  axs[i][8].imshow(im, vmin = 0, vmax=225)
  axs[0][8].set_title('Vascular Lesion', fontsize=10)

# %% [markdown]
# ## Cancer Detection With Convolutional Connected Network (CNN)
# #### Create train and validation data from our cropped images for our CNN

# %%
df_train, df_test = train_test_split(train_data,
                                     test_size=.2,
                                     stratify=train_data.label,
                                     shuffle=True,
                                     random_state=41)

# %%
# Set image size and batch size for training
image_size = (256, 256)
batch_size = 1700

# Create data gen object for data augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
)

# Conduct data augmentation on train data
train_generator = datagen.flow_from_dataframe(
    df_train,
    x_col='image',
    y_col='label',
    target_size=image_size,
    batch_size=batch_size,
    shuffle=True
)

# Conduct data augmentation on test data
test_generator = datagen.flow_from_dataframe(
    df_test,
    x_col='image',
    y_col='label',
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 1791 validated image filenames belonging to 9 classes.
# Found 448 validated image filenames belonging to 9 classes.

# %%
# Get train data and labels by iterating with our train data generator
train_iter = iter(train_generator)
train_data, train_labels = next(train_iter)

# %%
# Setting seed and reshaping data for training
sm = SMOTE(random_state=41)
train_data, train_labels = sm.fit_resample(train_data.reshape(-1, 256 * 256 * 3), train_labels)
train_data = train_data.reshape(-1, 256,256, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (3060, 256, 256, 3) (3060, 9)

# %%
# Printing out our data keys
class_num=list(train_generator.class_indices.keys())
class_num
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# ### Define the architecture of our CNN Model

# %%
from tensorflow.keras import backend as K

# Clearing previous models from memory
K.clear_session()

# Intialize a sequential model
model_cnn=keras.models.Sequential()

# Add first convolution layer of 32 filters of size 3x3 with stride 2
model_cnn.add(keras.layers.Conv2D(32,kernel_size=(3,3),strides=2,padding='same',activation='relu',input_shape=(256,256, 3)))
# Add a max pooling layer of size 2x2 with stride 2
model_cnn.add(keras.layers.MaxPool2D(pool_size=(2,2),strides=2,padding='same'))

# Add second convolution layer of 64 filters of size 3x3 with stride 2
model_cnn.add(keras.layers.Conv2D(64,kernel_size=(3,3),strides=2,activation='relu',padding='same'))
# Add a max pooling layer of size 2x2 with stride 2
model_cnn.add(keras.layers.MaxPool2D((2,2),2,padding='same'))

# Add third convolution layer of 128 filters of size 3x3 with stride 2
model_cnn.add(keras.layers.Conv2D(128,kernel_size=(3,3),strides=2,activation='relu',padding='same'))
# Add a thrid max pooling layer of size 2x2 with stride 2
model_cnn.add(keras.layers.MaxPool2D((2,2),2,padding='same'))

# Flatten output from previous layers
model_cnn.add(keras.layers.Flatten())

# Add a fully connected dense layer of 1024 neurons
model_cnn.add(keras.layers.Dense(1024,activation='relu'))

# Add dropout layer (30% of neurons will be randomly turned off to prevent overfitting)
model_cnn.add(keras.layers.Dropout(0.3))

# Add output layer of 9 neuros (one for each class)
model_cnn.add(keras.layers.Dense(9,activation='softmax'))

# Display model architecture
model_cnn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           9,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,200,649 (8.39 MB)
#  Trainable params: 2,200,649 (8.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Define Handy Callback Function

# %%
# Folder name to save our model
model_folder = 'model_cnn'
# Path to save our CNN model to
checkpoint_file = os.path.join(dirpath, model_folder, 'checkpoint.model.keras')
# Saves the model only if its performance improves
checkpoint_cb = ModelCheckpoint(checkpoint_file, save_best_only=True)
# Stop early if model's performance doesn't imporve for 5 epochs
early_stopping_cb =EarlyStopping(patience=5, restore_best_weights=True)
# Model compilation
model_cnn.compile(optimizer ='adam', loss='categorical_crossentropy', metrics=['accuracy',keras.metrics.SpecificityAtSensitivity(0.5),keras.metrics.AUC()])
# Train our model
hist=model_cnn.fit(train_data,
               train_labels,
               validation_split=.1,
               epochs=50,
               callbacks=[checkpoint_cb,early_stopping_cb])
# Out:
# Epoch 1/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 62s 676ms/step - accuracy: 0.1339 - auc: 0.5744 - loss: 2.1562 - specificity_at_sensitivity: 0.5144 - val_accuracy: 0.0000e+00 - val_auc: 0.4239 - val_loss: 2.4700 - val_specificity_at_sensitivity: 0.3795
# Epoch 2/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 85s 714ms/step - accuracy: 0.2848 - auc: 0.7669 - loss: 1.8002 - specificity_at_sensitivity: 0.8106 - val_accuracy: 0.0065 - val_auc: 0.4896 - val_loss: 2.5533 - val_specificity_at_sensitivity: 0.5114
# Epoch 3/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 84s 727ms/step - accuracy: 0.3316 - auc: 0.8056 - loss: 1.6864 - specificity_at_sensitivity: 0.8521 - val_accuracy: 0.5850 - val_auc: 0.9144 - val_loss: 1.0964 - val_specificity_at_sensitivity: 0.9996
# Epoch 4/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 77s 677ms/step - accuracy: 0.4183 - auc: 0.8535 - loss: 1.4913 - specificity_at_sensitivity: 0.9092 - val_accuracy: 0.6601 - val_auc: 0.9368 - val_loss: 0.9531 - val_specificity_at_sensitivity: 1.0000
# Epoch 5/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 81s 670ms/step - accuracy: 0.3994 - auc: 0.8429 - loss: 1.5434 - specificity_at_sensitivity: 0.8936 - val_accuracy: 0.3856 - val_auc: 0.8252 - val_loss: 1.6257 - val_specificity_at_sensitivity: 0.8819
# Epoch 6/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 83s 684ms/step - accuracy: 0.4471 - auc: 0.8684 - loss: 1.4264 - specificity_at_sensitivity: 0.9213 - val_accuracy: 0.6765 - val_auc: 0.9281 - val_loss: 1.0337 - val_specificity_at_sensitivity: 0.9971
# Epoch 7/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 80s 663ms/step - accuracy: 0.5112 - auc: 0.8899 - loss: 1.3120 - specificity_at_sensitivity: 0.9438 - val_accuracy: 0.6667 - val_auc: 0.9529 - val_loss: 0.8560 - val_specificity_at_sensitivity: 0.9980
# Epoch 8/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 86s 709ms/step - accuracy: 0.5106 - auc: 0.8908 - loss: 1.3037 - specificity_at_sensitivity: 0.9461 - val_accuracy: 0.7320 - val_auc: 0.9758 - val_loss: 0.6105 - val_specificity_at_sensitivity: 1.0000
# Epoch 9/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 80s 683ms/step - accuracy: 0.5317 - auc: 0.9066 - loss: 1.2127 - specificity_at_sensitivity: 0.9545 - val_accuracy: 0.7712 - val_auc: 0.9734 - val_loss: 0.6373 - val_specificity_at_sensitivity: 1.0000
# Epoch 10/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 58s 664ms/step - accuracy: 0.5425 - auc: 0.9090 - loss: 1.2000 - specificity_at_sensitivity: 0.9561 - val_accuracy: 0.6242 - val_auc: 0.9483 - val_loss: 0.9148 - val_specificity_at_sensitivity: 0.9959
# Epoch 11/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 86s 715ms/step - accuracy: 0.5879 - auc: 0.9174 - loss: 1.1434 - specificity_at_sensitivity: 0.9668 - val_accuracy: 0.6405 - val_auc: 0.9513 - val_loss: 0.8757 - val_specificity_at_sensitivity: 0.9906
# Epoch 12/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 78s 671ms/step - accuracy: 0.5855 - auc: 0.9220 - loss: 1.1120 - specificity_at_sensitivity: 0.9678 - val_accuracy: 0.8301 - val_auc: 0.9863 - val_loss: 0.4848 - val_specificity_at_sensitivity: 1.0000
# Epoch 13/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 60s 689ms/step - accuracy: 0.6596 - auc: 0.9451 - loss: 0.9354 - specificity_at_sensitivity: 0.9820 - val_accuracy: 0.8203 - val_auc: 0.9864 - val_loss: 0.4690 - val_specificity_at_sensitivity: 1.0000
# Epoch 14/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 80s 660ms/step - accuracy: 0.6514 - auc: 0.9440 - loss: 0.9462 - specificity_at_sensitivity: 0.9792 - val_accuracy: 0.7549 - val_auc: 0.9780 - val_loss: 0.5990 - val_specificity_at_sensitivity: 1.0000
# Epoch 15/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 85s 704ms/step - accuracy: 0.6993 - auc: 0.9563 - loss: 0.8307 - specificity_at_sensitivity: 0.9897 - val_accuracy: 0.8856 - val_auc: 0.9918 - val_loss: 0.3649 - val_specificity_at_sensitivity: 1.0000
# Epoch 16/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 59s 672ms/step - accuracy: 0.7363 - auc: 0.9667 - loss: 0.7236 - specificity_at_sensitivity: 0.9925 - val_accuracy: 0.8693 - val_auc: 0.9914 - val_loss: 0.3692 - val_specificity_at_sensitivity: 1.0000
# Epoch 17/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 82s 687ms/step - accuracy: 0.7666 - auc: 0.9711 - loss: 0.6745 - specificity_at_sensitivity: 0.9939 - val_accuracy: 0.8170 - val_auc: 0.9816 - val_loss: 0.5146 - val_specificity_at_sensitivity: 0.9996
# Epoch 18/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 74s 594ms/step - accuracy: 0.8012 - auc: 0.9794 - loss: 0.5651 - specificity_at_sensitivity: 0.9956 - val_accuracy: 0.8399 - val_auc: 0.9863 - val_loss: 0.4471 - val_specificity_at_sensitivity: 0.9996
# Epoch 19/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 81s 591ms/step - accuracy: 0.7907 - auc: 0.9763 - loss: 0.6002 - specificity_at_sensitivity: 0.9945 - val_accuracy: 0.9444 - val_auc: 0.9987 - val_loss: 0.1734 - val_specificity_at_sensitivity: 1.0000
# Epoch 20/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 84s 614ms/step - accuracy: 0.8631 - auc: 0.9889 - loss: 0.4037 - specificity_at_sensitivity: 0.9983 - val_accuracy: 0.9641 - val_auc: 0.9995 - val_loss: 0.1163 - val_specificity_at_sensitivity: 1.0000
# Epoch 21/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 78s 578ms/step - accuracy: 0.8785 - auc: 0.9909 - loss: 0.3641 - specificity_at_sensitivity: 0.9991 - val_accuracy: 0.9379 - val_auc: 0.9989 - val_loss: 0.1410 - val_specificity_at_sensitivity: 1.0000
# Epoch 22/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 82s 579ms/step - accuracy: 0.8853 - auc: 0.9910 - loss: 0.3390 - specificity_at_sensitivity: 0.9987 - val_accuracy: 0.9444 - val_auc: 0.9982 - val_loss: 0.1688 - val_specificity_at_sensitivity: 1.0000
# Epoch 23/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 82s 586ms/step - accuracy: 0.9010 - auc: 0.9933 - loss: 0.2998 - specificity_at_sensitivity: 0.9991 - val_accuracy: 0.9314 - val_auc: 0.9981 - val_loss: 0.1692 - val_specificity_at_sensitivity: 1.0000
# Epoch 24/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 82s 585ms/step - accuracy: 0.8184 - auc: 0.9817 - loss: 0.5086 - specificity_at_sensitivity: 0.9975 - val_accuracy: 0.9641 - val_auc: 0.9990 - val_loss: 0.1268 - val_specificity_at_sensitivity: 1.0000
# Epoch 25/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 84s 600ms/step - accuracy: 0.8941 - auc: 0.9923 - loss: 0.3025 - specificity_at_sensitivity: 0.9988 - val_accuracy: 0.9673 - val_auc: 0.9992 - val_loss: 0.1102 - val_specificity_at_sensitivity: 1.0000
# Epoch 26/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 81s 592ms/step - accuracy: 0.8643 - auc: 0.9881 - loss: 0.4001 - specificity_at_sensitivity: 0.9981 - val_accuracy: 0.9314 - val_auc: 0.9940 - val_loss: 0.2191 - val_specificity_at_sensitivity: 1.0000
# Epoch 27/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 51s 582ms/step - accuracy: 0.9189 - auc: 0.9943 - loss: 0.2483 - specificity_at_sensitivity: 0.9994 - val_accuracy: 0.9804 - val_auc: 0.9996 - val_loss: 0.0867 - val_specificity_at_sensitivity: 1.0000
# Epoch 28/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 56s 642ms/step - accuracy: 0.9379 - auc: 0.9972 - loss: 0.1913 - specificity_at_sensitivity: 0.9997 - val_accuracy: 0.9837 - val_auc: 0.9999 - val_loss: 0.0491 - val_specificity_at_sensitivity: 1.0000
# Epoch 29/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 82s 645ms/step - accuracy: 0.9462 - auc: 0.9980 - loss: 0.1576 - specificity_at_sensitivity: 0.9997 - val_accuracy: 0.9641 - val_auc: 0.9991 - val_loss: 0.1171 - val_specificity_at_sensitivity: 1.0000
# Epoch 30/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 58s 666ms/step - accuracy: 0.9262 - auc: 0.9963 - loss: 0.2135 - specificity_at_sensitivity: 0.9996 - val_accuracy: 0.9869 - val_auc: 0.9999 - val_loss: 0.0540 - val_specificity_at_sensitivity: 1.0000
# Epoch 31/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 58s 666ms/step - accuracy: 0.9229 - auc: 0.9961 - loss: 0.2353 - specificity_at_sensitivity: 0.9997 - val_accuracy: 0.9575 - val_auc: 0.9973 - val_loss: 0.1304 - val_specificity_at_sensitivity: 0.9996
# Epoch 32/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 83s 678ms/step - accuracy: 0.9119 - auc: 0.9956 - loss: 0.2354 - specificity_at_sensitivity: 0.9996 - val_accuracy: 0.9804 - val_auc: 0.9998 - val_loss: 0.0555 - val_specificity_at_sensitivity: 1.0000
# Epoch 33/50
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 84s 693ms/step - accuracy: 0.9586 - auc: 0.9987 - loss: 0.1298 - specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9673 - val_auc: 0.9994 - val_loss: 0.0926 - val_specificity_at_sensitivity: 1.0000

# %% [markdown]
# ### Outputting Results of Model

# %%
# Create a dataframe of our training session and store it in google drive
hist_cnn=pd.DataFrame(hist.history)
hist_cnn.to_csv('/content/drive/MyDrive/Skin_Lesion_Project/output.csv', index=False)
hist_cnn
# Out:
#     accuracy       auc      loss  specificity_at_sensitivity  val_accuracy  \
# 0   0.167030  0.633781  2.085195                    0.588644      0.000000
# 1   0.308279  0.789724  1.732739                    0.839234      0.006536
# 2   0.368555  0.833676  1.579863                    0.879221      0.584967
# 3   0.435004  0.864624  1.445768                    0.914443      0.660131
# 4   0.412128  0.848881  1.515802                    0.904321      0.385621
# 5   0.481118  0.882567  1.356082                    0.936048      0.676471
# 6   0.510893  0.893215  1.294269                    0.945216      0.666667
# 7   0.528322  0.899177  1.258188                    0.951434      0.732026
# 8   0.546478  0.908574  1.199633                    0.959604      0.771242
# 9   0.553377  0.912195  1.177538                    0.961374      0.624183
# 10  0.593682  0.921473  1.114643                    0.967229      0.640523
# 11  0.614379  0.930113  1.052404                    0.973675      0.830065
# 12  0.650690  0.941518  0.961393                    0.980256      0.820261
# 13  0.688816  0.952079  0.876985                    0.985612      0.754902
# 14  0.713145  0.960135  0.792536                    0.990559      0.885621
# 15  0.738562  0.965414  0.731858                    0.992239      0.869281
# 16  0.765069  0.971718  0.664825                    0.994190      0.816993
# 17  0.800290  0.978489  0.572371                    0.995189      0.839869
# 18  0.809368  0.980168  0.554954                    0.996324      0.944444
# 19  0.848584  0.986741  0.437664                    0.998003      0.964052
# 20  0.883805  0.991547  0.349632                    0.998684      0.937908
# 21  0.884895  0.991800  0.336102                    0.998729      0.944444
# 22  0.897240  0.993130  0.304738                    0.999183      0.931373
# 23  0.845316  0.986801  0.431659                    0.997776      0.964052
# 24  0.900871  0.992613  0.292740                    0.999001      0.967320
# 25  0.886347  0.990889  0.340963                    0.998684      0.931373
# 26  0.919027  0.995096  0.237033                    0.999274      0.980392
# 27  0.934641  0.996585  0.200041                    0.999455      0.983660
# 28  0.935730  0.996696  0.190287                    0.999592      0.964052
# 29  0.923021  0.995760  0.223510                    0.999501      0.986928
# 30  0.932099  0.997054  0.204040                    0.999773      0.957516
# 31  0.927741  0.996399  0.206654                    0.999592      0.980392
# 32  0.949891  0.998029  0.154099                    0.999818      0.967320
#
#      val_auc  val_loss  val_specificity_at_sensitivity
# 0   0.423905  2.470019                        0.379493
# 1   0.489583  2.553346                        0.511438
# 2   0.914427  1.096372                        0.999592
# 3   0.936791  0.953079                        1.000000
# 4   0.825226  1.625680                        0.881944
# 5   0.928089  1.033664                        0.997141
# 6   0.952944  0.855995                        0.997958
# 7   0.975757  0.610517                        1.000000
# 8   0.973422  0.637251                        1.000000
# 9   0.948332  0.914772                        0.995915
# 10  0.951332  0.875671                        0.990605
# 11  0.986284  0.484833                        1.000000
# 12  0.986447  0.469047                        1.000000
# 13  0.977965  0.598966                        1.000000
# 14  0.991839  0.364939                        1.000000
# 15  0.991428  0.369238                        1.000000
# 16  0.981589  0.514609                        0.999592
# 17  0.986324  0.447106                        0.999592
# 18  0.998674  0.173407                        1.000000
# 19  0.999513  0.116323                        1.000000
# 20  0.998863  0.141042                        1.000000
# 21  0.998168  0.168817                        1.000000
# 22  0.998139  0.169204                        1.000000
# 23  0.999039  0.126822                        1.000000
# 24  0.999218  0.110175                        1.000000
# 25  0.993993  0.219117                        1.000000
# 26  0.999567  0.086713                        1.000000
# 27  0.999865  0.049144                        1.000000
# 28  0.999120  0.117108                        1.000000
# 29  0.999853  0.053970                        1.000000
# 30  0.997286  0.130353                        0.999592
# 31  0.999821  0.055492                        1.000000
# 32  0.999381  0.092628                        1.000000

# %% [markdown]
# ### Plot training and validation accuracy to assess model training

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.plot(hist_cnn.iloc[:,0],'b-o',label='Train_Loss')
plt.plot(hist_cnn.iloc[:,4],'r-o',label='Validation_Loss')
plt.title('Train_Loss & Validation_Loss',fontsize=20)
plt.legend()
plt.subplot(2,2,2)
plt.plot(hist_cnn.iloc[:,1],'b-o',label='Train_Accuracy')
plt.plot(hist_cnn.iloc[:,5],'r-o',label='Validation_Accuracy')
plt.title('Train_Accuracy & Validation_Accuracy',fontsize=20)
plt.legend()
plt.subplot(2,2,3)
plt.plot(hist_cnn.iloc[:,2],'b-o',label='Train_specificity_at_sensitivity')
plt.plot(hist_cnn.iloc[:,6],'r-o',label='Validation_specificity_at_sensitivity')
plt.title('Train_Sensitivity & Validation_Sensitivity',fontsize=20)
plt.legend()
plt.subplot(2,2,4)
plt.plot(hist_cnn.iloc[:,3],'b-o',label='Train_auc')
plt.plot(hist_cnn.iloc[:,7],'r-o',label='Validation_auc')
plt.title('Train_AUC & Validation_AUC',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Model Evaluation

# %%
score, acc,sensitivity,auc = model_cnn.evaluate(test_generator)
print('Test Loss =', score)
print('Test Accuracy =', acc)
print('Test Sensitivity =', sensitivity)
print('Test AUC =', auc)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5179 - auc: 0.8579 - loss: 2.2096 - specificity_at_sensitivity: 0.9442
# Test Loss = 2.209590435028076
# Test Accuracy = 0.5178571343421936
# Test Sensitivity = 0.9441964030265808
# Test AUC = 0.857923150062561

# %% [markdown]
# #### F1 score

# %%
# Make predictions on the validation set
y_val_pred = model_cnn.predict(train_data)

# Convert predictions from probabilities to class labels
y_val_pred_classes = np.argmax(y_val_pred, axis=1)
y_val_true_classes = np.argmax(train_labels, axis=1)  # Convert true labels if in categorical format

# Calculate the F1 score
f1 = f1_score(y_val_true_classes, y_val_pred_classes, average='weighted')

print(f"F1 Score: {f1:.4f}")
# Out:
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step
# F1 Score: 0.9590

# %% [markdown]
# ### Transfer files to Google Drive

# %% [markdown]
# ## Improving CNN Training with Data Augmentation and Dropout
#
# #### We will be implementing data augmentation and adding a dropout layer to help solve the issue with overfitting in our model.

# %%
# Create data gen with object with parameters for data augmentation
datagen2 = ImageDataGenerator(
    rotation_range = 10,
    zoom_range = 0.1,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    vertical_flip = False,
    rescale=1./255,
)

# %%
# Set image size and batch size for training
image_size = (256, 256)
batch_size = 1700

# Conduct data augmentation on train data
train_generator2 = datagen2.flow_from_dataframe(
    df_train,
    x_col='image',
    y_col='label',
    target_size=image_size,
    batch_size=batch_size,
    shuffle=True
)

# Conduct data augmentation on test data
test_generator2 = datagen2.flow_from_dataframe(
    df_test,
    x_col='image',
    y_col='label',
    target_size=image_size,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 1791 validated image filenames belonging to 9 classes.
# Found 448 validated image filenames belonging to 9 classes.

# %%
# Get train data and labels by iterating with our train data generator
train_iter2 = iter(train_generator2)
train_data, train_labels = next(train_iter2)

# %%
# Setting seed and reshaping data for training
sm = SMOTE(random_state=41)
train_data, train_labels = sm.fit_resample(train_data.reshape(-1, 256 * 256 * 3), train_labels)
train_data = train_data.reshape(-1, 256,256, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (3177, 256, 256, 3) (3177, 9)

# %% [markdown]
# ### Define Same CNN Architecture
# This time add dropout layer to prevent overfitting

# %%
from tensorflow.keras import backend as K

# Clearing previous models from memory
K.clear_session()

# Intialize a sequential model
model_cnn_aug=keras.models.Sequential()

# Add first convolution layer of 32 filters of size 3x3 with stride 2
model_cnn_aug.add(keras.layers.Conv2D(32,kernel_size=(3,3),strides=2,padding='same',activation='relu',input_shape=(256,256, 3)))
# Add a max pooling layer of size 2x2 with stride 2
model_cnn_aug.add(keras.layers.MaxPool2D(pool_size=(2,2),strides=2,padding='same'))

# Add second convolution layer of 64 filters of size 3x3 with stride 2
model_cnn_aug.add(keras.layers.Conv2D(64,kernel_size=(3,3),strides=2,activation='relu',padding='same'))
# Add a max pooling layer of size 2x2 with stride 2
model_cnn_aug.add(keras.layers.MaxPool2D((2,2),2,padding='same'))

# Add third convolution layer of 128 filters of size 3x3 with stride 2
model_cnn_aug.add(keras.layers.Conv2D(128,kernel_size=(3,3),strides=2,activation='relu',padding='same'))
# Add a thrid max pooling layer of size 2x2 with stride 2
model_cnn_aug.add(keras.layers.MaxPool2D((2,2),2,padding='same'))

# Flatten output from previous layers
model_cnn_aug.add(keras.layers.Flatten())

# Add a fully connected dense layer of 1024 neurons
model_cnn_aug.add(keras.layers.Dense(1024,activation='relu'))

# Add dropout layer (30% of neurons will be randomly turned off to prevent overfitting)
model_cnn_aug.add(keras.layers.Dropout(0.3))

# Add output layer of 9 neuros (one for each class)
model_cnn_aug.add(keras.layers.Dense(9,activation='softmax'))

# Display model architecture
model_cnn_aug.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           9,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,200,649 (8.39 MB)
#  Trainable params: 2,200,649 (8.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Define Handy Call Back Functions and Train Model

# %%
# Folder name to save our model
model_folder = 'model_cnn_aug'
# Path to save our CNN model to
checkpoint_file = os.path.join(dirpath, model_folder, 'checkpoint.model.keras')
# Saves the model only if its performance improves
checkpoint_cb = ModelCheckpoint(checkpoint_file, save_best_only=True)
# Stop early if model's performance doesn't imporve for 5 epochs
early_stopping_cb =EarlyStopping(patience=5, restore_best_weights=True)
# Model compilation
model_cnn_aug.compile(optimizer ='adam', loss='categorical_crossentropy', metrics=['accuracy',keras.metrics.SpecificityAtSensitivity(0.5),keras.metrics.AUC()])
# Train our model
hist_aug=model_cnn_aug.fit(train_data,
               train_labels,
               validation_split=.1,
               epochs=50,
               callbacks=[checkpoint_cb,early_stopping_cb])
# Out:
# Epoch 1/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 73s 778ms/step - accuracy: 0.1609 - auc: 0.6254 - loss: 2.0924 - specificity_at_sensitivity: 0.6267 - val_accuracy: 0.0000e+00 - val_auc: 0.4199 - val_loss: 2.5433 - val_specificity_at_sensitivity: 0.3687
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 66s 607ms/step - accuracy: 0.2886 - auc: 0.7769 - loss: 1.7829 - specificity_at_sensitivity: 0.8232 - val_accuracy: 0.1006 - val_auc: 0.6309 - val_loss: 2.0385 - val_specificity_at_sensitivity: 0.5947
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 84s 636ms/step - accuracy: 0.3804 - auc: 0.8412 - loss: 1.5603 - specificity_at_sensitivity: 0.8897 - val_accuracy: 0.5031 - val_auc: 0.8729 - val_loss: 1.2958 - val_specificity_at_sensitivity: 0.9796
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 79s 599ms/step - accuracy: 0.4352 - auc: 0.8629 - loss: 1.4561 - specificity_at_sensitivity: 0.9129 - val_accuracy: 0.3836 - val_auc: 0.8089 - val_loss: 1.6624 - val_specificity_at_sensitivity: 0.8656
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 88s 663ms/step - accuracy: 0.4302 - auc: 0.8678 - loss: 1.4282 - specificity_at_sensitivity: 0.9208 - val_accuracy: 0.6478 - val_auc: 0.9292 - val_loss: 0.9983 - val_specificity_at_sensitivity: 0.9996
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 78s 616ms/step - accuracy: 0.4751 - auc: 0.8856 - loss: 1.3391 - specificity_at_sensitivity: 0.9350 - val_accuracy: 0.6352 - val_auc: 0.9326 - val_loss: 0.9935 - val_specificity_at_sensitivity: 0.9996
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 54s 602ms/step - accuracy: 0.5250 - auc: 0.9018 - loss: 1.2533 - specificity_at_sensitivity: 0.9511 - val_accuracy: 0.6384 - val_auc: 0.9466 - val_loss: 0.9090 - val_specificity_at_sensitivity: 0.9992
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 55s 613ms/step - accuracy: 0.5362 - auc: 0.9092 - loss: 1.2004 - specificity_at_sensitivity: 0.9553 - val_accuracy: 0.5000 - val_auc: 0.9063 - val_loss: 1.2296 - val_specificity_at_sensitivity: 0.9532
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 84s 646ms/step - accuracy: 0.5715 - auc: 0.9181 - loss: 1.1386 - specificity_at_sensitivity: 0.9632 - val_accuracy: 0.7327 - val_auc: 0.9688 - val_loss: 0.6830 - val_specificity_at_sensitivity: 0.9992
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 85s 679ms/step - accuracy: 0.6000 - auc: 0.9282 - loss: 1.0684 - specificity_at_sensitivity: 0.9716 - val_accuracy: 0.7013 - val_auc: 0.9603 - val_loss: 0.7860 - val_specificity_at_sensitivity: 1.0000
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 80s 657ms/step - accuracy: 0.6368 - auc: 0.9379 - loss: 0.9925 - specificity_at_sensitivity: 0.9774 - val_accuracy: 0.7453 - val_auc: 0.9758 - val_loss: 0.6071 - val_specificity_at_sensitivity: 1.0000
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 84s 683ms/step - accuracy: 0.6750 - auc: 0.9468 - loss: 0.9211 - specificity_at_sensitivity: 0.9830 - val_accuracy: 0.7925 - val_auc: 0.9769 - val_loss: 0.5959 - val_specificity_at_sensitivity: 1.0000
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 84s 706ms/step - accuracy: 0.7108 - auc: 0.9594 - loss: 0.8102 - specificity_at_sensitivity: 0.9896 - val_accuracy: 0.7516 - val_auc: 0.9684 - val_loss: 0.6968 - val_specificity_at_sensitivity: 0.9980
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 63s 701ms/step - accuracy: 0.7354 - auc: 0.9656 - loss: 0.7335 - specificity_at_sensitivity: 0.9922 - val_accuracy: 0.8302 - val_auc: 0.9876 - val_loss: 0.4478 - val_specificity_at_sensitivity: 1.0000
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 78s 664ms/step - accuracy: 0.7568 - auc: 0.9695 - loss: 0.6874 - specificity_at_sensitivity: 0.9943 - val_accuracy: 0.8742 - val_auc: 0.9910 - val_loss: 0.3803 - val_specificity_at_sensitivity: 1.0000
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 83s 682ms/step - accuracy: 0.7886 - auc: 0.9763 - loss: 0.6054 - specificity_at_sensitivity: 0.9964 - val_accuracy: 0.8994 - val_auc: 0.9924 - val_loss: 0.3221 - val_specificity_at_sensitivity: 1.0000
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 76s 610ms/step - accuracy: 0.8496 - auc: 0.9860 - loss: 0.4620 - specificity_at_sensitivity: 0.9979 - val_accuracy: 0.8931 - val_auc: 0.9927 - val_loss: 0.3066 - val_specificity_at_sensitivity: 1.0000
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 81s 603ms/step - accuracy: 0.8588 - auc: 0.9882 - loss: 0.4069 - specificity_at_sensitivity: 0.9989 - val_accuracy: 0.8774 - val_auc: 0.9913 - val_loss: 0.3467 - val_specificity_at_sensitivity: 1.0000
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 82s 611ms/step - accuracy: 0.8564 - auc: 0.9859 - loss: 0.4388 - specificity_at_sensitivity: 0.9985 - val_accuracy: 0.8365 - val_auc: 0.9859 - val_loss: 0.4509 - val_specificity_at_sensitivity: 0.9988
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 82s 609ms/step - accuracy: 0.9152 - auc: 0.9949 - loss: 0.2694 - specificity_at_sensitivity: 0.9992 - val_accuracy: 0.9277 - val_auc: 0.9965 - val_loss: 0.2341 - val_specificity_at_sensitivity: 1.0000
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 80s 584ms/step - accuracy: 0.9082 - auc: 0.9952 - loss: 0.2732 - specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9371 - val_auc: 0.9971 - val_loss: 0.2115 - val_specificity_at_sensitivity: 1.0000
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 54s 599ms/step - accuracy: 0.9243 - auc: 0.9959 - loss: 0.2325 - specificity_at_sensitivity: 0.9996 - val_accuracy: 0.8899 - val_auc: 0.9946 - val_loss: 0.2852 - val_specificity_at_sensitivity: 1.0000
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 81s 587ms/step - accuracy: 0.9146 - auc: 0.9962 - loss: 0.2398 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9465 - val_auc: 0.9969 - val_loss: 0.1608 - val_specificity_at_sensitivity: 1.0000
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 86s 635ms/step - accuracy: 0.9535 - auc: 0.9987 - loss: 0.1399 - specificity_at_sensitivity: 0.9999 - val_accuracy: 0.8899 - val_auc: 0.9909 - val_loss: 0.2820 - val_specificity_at_sensitivity: 0.9996
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 78s 589ms/step - accuracy: 0.9496 - auc: 0.9981 - loss: 0.1479 - specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9528 - val_auc: 0.9981 - val_loss: 0.1683 - val_specificity_at_sensitivity: 1.0000
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 87s 646ms/step - accuracy: 0.9466 - auc: 0.9983 - loss: 0.1537 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.8899 - val_auc: 0.9958 - val_loss: 0.2584 - val_specificity_at_sensitivity: 1.0000
# Epoch 27/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 77s 590ms/step - accuracy: 0.9182 - auc: 0.9920 - loss: 0.2831 - specificity_at_sensitivity: 0.9994 - val_accuracy: 0.9591 - val_auc: 0.9972 - val_loss: 0.1521 - val_specificity_at_sensitivity: 1.0000
# Epoch 28/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 56s 625ms/step - accuracy: 0.9638 - auc: 0.9984 - loss: 0.1194 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9686 - val_auc: 0.9978 - val_loss: 0.1067 - val_specificity_at_sensitivity: 1.0000
# Epoch 29/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 80s 605ms/step - accuracy: 0.9627 - auc: 0.9993 - loss: 0.1037 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9497 - val_auc: 0.9957 - val_loss: 0.1572 - val_specificity_at_sensitivity: 1.0000
# Epoch 30/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 81s 595ms/step - accuracy: 0.9710 - auc: 0.9989 - loss: 0.0920 - specificity_at_sensitivity: 0.9999 - val_accuracy: 0.9623 - val_auc: 0.9979 - val_loss: 0.0956 - val_specificity_at_sensitivity: 1.0000
# Epoch 31/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 57s 632ms/step - accuracy: 0.9860 - auc: 0.9989 - loss: 0.0537 - specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9811 - val_auc: 0.9967 - val_loss: 0.0660 - val_specificity_at_sensitivity: 1.0000
# Epoch 32/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 80s 613ms/step - accuracy: 0.9815 - auc: 0.9986 - loss: 0.0722 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9591 - val_auc: 0.9975 - val_loss: 0.1384 - val_specificity_at_sensitivity: 1.0000
# Epoch 33/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 85s 646ms/step - accuracy: 0.9805 - auc: 0.9998 - loss: 0.0567 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9717 - val_auc: 0.9993 - val_loss: 0.0978 - val_specificity_at_sensitivity: 1.0000
# Epoch 34/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 77s 588ms/step - accuracy: 0.9812 - auc: 0.9990 - loss: 0.0573 - specificity_at_sensitivity: 0.9998 - val_accuracy: 0.9340 - val_auc: 0.9954 - val_loss: 0.1730 - val_specificity_at_sensitivity: 1.0000
# Epoch 35/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 54s 599ms/step - accuracy: 0.9769 - auc: 0.9993 - loss: 0.0751 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9465 - val_auc: 0.9954 - val_loss: 0.1615 - val_specificity_at_sensitivity: 0.9996
# Epoch 36/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 81s 587ms/step - accuracy: 0.9677 - auc: 0.9991 - loss: 0.0952 - specificity_at_sensitivity: 1.0000 - val_accuracy: 0.9654 - val_auc: 0.9979 - val_loss: 0.1041 - val_specificity_at_sensitivity: 1.0000

# %% [markdown]
# ### Outputting Results of Model Training

# %%
# Create a dataframe of our training session and store it in google drive
hist_cnn_aug=pd.DataFrame(hist_aug.history)
hist_cnn_aug.to_csv('/content/drive/MyDrive/Skin_Lesion_Project/output_aug.csv', index=False)
hist_cnn_aug
# Out:
#     accuracy       auc      loss  specificity_at_sensitivity  val_accuracy  \
# 0   0.218958  0.712660  1.941181                    0.739507      0.000000
# 1   0.314795  0.791798  1.732657                    0.841859      0.100629
# 2   0.384050  0.842438  1.546096                    0.893800      0.503145
# 3   0.433368  0.861276  1.461481                    0.909496      0.383648
# 4   0.441413  0.866796  1.434721                    0.917760      0.647799
# 5   0.485484  0.886180  1.335418                    0.937260      0.635220
# 6   0.523959  0.898072  1.268126                    0.949589      0.638365
# 7   0.544596  0.910813  1.188694                    0.958465      0.500000
# 8   0.585170  0.922691  1.108487                    0.969089      0.732704
# 9   0.598461  0.927789  1.072079                    0.970269      0.701258
# 10  0.632039  0.936985  0.999015                    0.976740      0.745283
# 11  0.670164  0.947236  0.915489                    0.983954      0.792453
# 12  0.721581  0.961155  0.787355                    0.990512      0.751572
# 13  0.736271  0.964977  0.742712                    0.992130      0.830189
# 14  0.755509  0.969911  0.681282                    0.994797      0.874214
# 15  0.805526  0.980749  0.548181                    0.997727      0.899371
# 16  0.844701  0.985986  0.461903                    0.998164      0.893082
# 17  0.856593  0.988719  0.405067                    0.999082      0.877358
# 18  0.850647  0.987090  0.433717                    0.998776      0.836478
# 19  0.910808  0.994503  0.273723                    0.999344      0.927673
# 20  0.906611  0.995106  0.271257                    0.999738      0.937107
# 21  0.915705  0.995559  0.243426                    0.999694      0.889937
# 22  0.931445  0.997427  0.196381                    0.999956      0.946541
# 23  0.950332  0.998182  0.152036                    0.999869      0.889937
# 24  0.951032  0.998417  0.142050                    0.999913      0.952830
# 25  0.942288  0.997545  0.171606                    0.999913      0.889937
# 26  0.933893  0.995567  0.215320                    0.999650      0.959119
# 27  0.962225  0.998228  0.123540                    0.999956      0.968553
# 28  0.952781  0.999029  0.123513                    1.000000      0.949686
# 29  0.972368  0.999192  0.083109                    0.999913      0.962264
# 30  0.981812  0.999124  0.063136                    0.999869      0.981132
# 31  0.980413  0.999144  0.068701                    0.999913      0.959119
# 32  0.979014  0.999783  0.058337                    1.000000      0.971698
# 33  0.979713  0.999379  0.060792                    0.999956      0.933962
# 34  0.980063  0.999076  0.070603                    0.999913      0.946541
# 35  0.973068  0.998736  0.085907                    0.999913      0.965409
#
#      val_auc  val_loss  val_specificity_at_sensitivity
# 0   0.419869  2.543316                        0.368711
# 1   0.630854  2.038532                        0.594733
# 2   0.872857  1.295821                        0.979560
# 3   0.808859  1.662418                        0.865566
# 4   0.929224  0.998277                        0.999607
# 5   0.932577  0.993542                        0.999607
# 6   0.946591  0.908970                        0.999214
# 7   0.906319  1.229591                        0.953223
# 8   0.968845  0.683030                        0.999214
# 9   0.960287  0.786025                        1.000000
# 10  0.975831  0.607078                        1.000000
# 11  0.976869  0.595947                        1.000000
# 12  0.968420  0.696766                        0.998035
# 13  0.987555  0.447844                        1.000000
# 14  0.991044  0.380254                        1.000000
# 15  0.992358  0.322128                        1.000000
# 16  0.992704  0.306646                        1.000000
# 17  0.991343  0.346691                        1.000000
# 18  0.985880  0.450920                        0.998821
# 19  0.996470  0.234117                        1.000000
# 20  0.997104  0.211460                        1.000000
# 21  0.994605  0.285193                        1.000000
# 22  0.996938  0.160760                        1.000000
# 23  0.990910  0.282028                        0.999607
# 24  0.998067  0.168340                        1.000000
# 25  0.995809  0.258374                        1.000000
# 26  0.997174  0.152084                        1.000000
# 27  0.997794  0.106692                        1.000000
# 28  0.995684  0.157230                        1.000000
# 29  0.997927  0.095637                        1.000000
# 30  0.996668  0.065978                        1.000000
# 31  0.997471  0.138445                        1.000000
# 32  0.999269  0.097776                        1.000000
# 33  0.995406  0.173002                        1.000000
# 34  0.995436  0.161508                        0.999607
# 35  0.997863  0.104059                        1.000000

# %% [markdown]
# ### Plot Training and Validation Accuracy of Augmented Model

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.plot(hist_cnn_aug.iloc[:,0],'b-o',label='Train_Loss_Aug')
plt.plot(hist_cnn_aug.iloc[:,4],'r-o',label='Validation_Loss')
plt.title('Train_Loss_Aug & Validation_Loss_Aug',fontsize=20)
plt.legend()
plt.subplot(2,2,2)
plt.plot(hist_cnn_aug.iloc[:,1],'b-o',label='Train_Accuracy_Aug')
plt.plot(hist_cnn_aug.iloc[:,5],'r-o',label='Validation_Accuracy_Aug')
plt.title('Train_Accuracy_Aug & Validation_Accuracy_Aug',fontsize=20)
plt.legend()
plt.subplot(2,2,3)
plt.plot(hist_cnn_aug.iloc[:,2],'b-o',label='Train_specificity_at_sensitivity_Aug')
plt.plot(hist_cnn_aug.iloc[:,6],'r-o',label='Validation_specificity_at_sensitivity_Aug')
plt.title('Train_Sensitivity_Aug & Validation_Sensitivity_Aug',fontsize=20)
plt.legend()
plt.subplot(2,2,4)
plt.plot(hist_cnn_aug.iloc[:,3],'b-o',label='Train_auc_Aug')
plt.plot(hist_cnn_aug.iloc[:,7],'r-o',label='Validation_auc_Aug')
plt.title('Train_AUC_Aug & Validation_AUC_Aug',fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Augmented CNN Model Evaluation

# %%
score_aug, acc_aug,sensitivity_aug,auc_aug = model_cnn_aug.evaluate(test_generator2)
print('Test Aug Loss =', score_aug)
print('Test Aug Accuracy =', acc_aug)
print('Test Aug Sensitivity =', sensitivity_aug)
print('Test Aug AUC =', auc_aug)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step - accuracy: 0.4955 - auc: 0.8069 - loss: 3.6680 - specificity_at_sensitivity: 0.9342
# Test Aug Loss = 3.6680030822753906
# Test Aug Accuracy = 0.4955357015132904
# Test Aug Sensitivity = 0.9341517686843872
# Test Aug AUC = 0.8069125413894653

# %% [markdown]
# ### F1 Score of Augmented Model

# %%
# Make predictions on the validation set
y_val_pred = model_cnn_aug.predict(train_data)

# Convert predictions from probabilities to class labels
y_val_pred_classes = np.argmax(y_val_pred, axis=1)
y_val_true_classes = np.argmax(train_labels, axis=1)  # Convert true labels if in categorical format

# Calculate the F1 score
f1 = f1_score(y_val_true_classes, y_val_pred_classes, average='weighted')

print(f"F1 Score: {f1:.4f}")
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 202ms/step
# F1 Score: 0.9915

# %% [markdown]
# ### Use our Augmented Model to Predict Test Data

# %%
y_test = test_generator2.classes
predictions = model_cnn_aug.predict(test_generator2)
y_pred = np.argmax(predictions,axis=1)
y_test = np.ravel(y_test)
y_pred = np.ravel(y_pred)
df = pd.DataFrame({'Actual': y_test, 'Prediction': y_pred})
df
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
#      Actual  Prediction
# 0         4           1
# 1         3           4
# 2         3           3
# 3         3           4
# 4         8           3
# ..      ...         ...
# 443       8           7
# 444       3           3
# 445       5           5
# 446       7           5
# 447       3           3
#
# [448 rows x 2 columns]

# %% [markdown]
# ### Confusion Matrix from Augmented Model

# %%
CM = confusion_matrix(y_test,y_pred)
sns.heatmap(CM,fmt='g',center = True,cbar=False,annot=True,cmap='Blues')
CM
# Out:
# array([[ 2,  6,  0,  0,  6,  4,  0,  4,  1],
#        [ 2, 44,  2,  2,  5,  3,  0, 12,  5],
#        [ 3,  2,  1,  2,  2,  1,  1,  6,  1],
#        [ 0,  5,  1, 55, 15,  3,  9,  0,  0],
#        [ 2,  8,  0, 17, 29,  7,  1,  6,  1],
#        [ 3, 10,  4,  5, 15, 45,  2,  7,  2],
#        [ 0,  0,  0, 12,  2,  1,  0,  0,  0],
#        [ 3,  7,  1,  0,  6, 10,  0,  8,  1],
#        [ 0,  1,  0,  1,  0,  1,  0,  2, 23]])

# %% [markdown]
# ## Using Augmented Model for Prediction

# %%
# Function to preprocess the image
def preprocess_image(image_path, target_size):
    img = cv2.imread(image_path, cv2.COLOR_BGR2RGB)  # Load image in RGB
    img = cv2.resize(img, target_size)  # Resize to target size
    img = img / 255.0  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Preprocess the image
target_size = (256, 256)  # Replace with your model's expected input size
image_path = '/content/Cropped_Images/vascular lesion/ISIC_0025197.jpg'  # Replace with the path to your image
img = preprocess_image(image_path, target_size)

# Class Labels
class_labels = {0:'actinic keratosis', 1: 'basal cell carcinoma', 2: 'dermatofibroma', 3:'melanoma', 4:'nevus',
                5:'pigmented benign keratosis', 6:'seborrheic keratosis', 7:'squamous cell carcinoma', 8:'vascular lesion'}
# Make a prediction
prediction = model_cnn_aug.predict(img)

# Interpret the result
predicted_class = np.argmax(prediction, axis=1)[0]
predicted_label = class_labels[predicted_class]
print(f"Predicted class: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Predicted class: vascular lesion

# %% [markdown]
# ### Zip Model Folders and Transfer Files to Google Drive

# %%
# Create a zip file of our CNN model
# !zip -r model_cnn.zip model_cnn
# Create a zip file of our Augmented CNN model
# !zip -r model_cnn_aug.zip model_cnn_aug
# Out:
#   adding: model_cnn/ (stored 0%)
#   adding: model_cnn/checkpoint.model.keras (deflated 12%)
#   adding: model_cnn_aug/ (stored 0%)
#   adding: model_cnn_aug/checkpoint.model.keras (deflated 17%)

# %%
# Transfer all files to our google drive folder
# !sudo cp -v -r "/content/Cropped_Images/" "/content/drive/MyDrive/Skin_Lesion_Project"
# !sudo cp -v -r "/content/Skin cancer ISIC The International Skin Imaging Collaboration/" "/content/drive/MyDrive/Skin_Lesion_Project"
# !sudo cp -v -r "/content/model_cnn/" "/content/drive/MyDrive/Skin_Lesion_Project"
# !sudo cp -v -r "/content/model_cnn.zip" "/content/drive/MyDrive/Skin_Lesion_Project"
# !sudo cp -v -r "/content/skin-cancer9-classesisic.zip" "/content/drive/MyDrive/Skin_Lesion_Project"
# !sudo cp -v -r "/content/model_cnn_aug/" "/content/drive/MyDrive/Skin_Lesion_Project"
# !sudo cp -v -r "/content/model_cnn_aug.zip" "/content/drive/MyDrive/Skin_Lesion_Project"
